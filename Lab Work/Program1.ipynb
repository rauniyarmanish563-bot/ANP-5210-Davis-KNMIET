# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/ANP-5210-Davis-KNMIET/blob/main/Lab%20Work/Program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function for set operations
def set_operations(s1, s2):
    return s1 & s2, s1 - s2

# Main
inter, diff = set_operations({1,2,3,4}, {3,4,5,6})
print("Intersection:", inter)
print("Difference:", diff)
# Out:
# Intersection: {3, 4}
# Difference: {1, 2}
